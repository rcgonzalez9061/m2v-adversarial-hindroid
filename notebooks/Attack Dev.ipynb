# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, f1_score
import pickle
from stellargraph import StellarGraph, IndexedArray
from stellargraph.data import UniformRandomMetaPathWalk
from p_tqdm import p_umap
from gensim.models import Word2Vec

# %%
import os
os.chdir('..')
# !pwd
# Out:
# /datasets/home/home-00/10/410/rcgonzal/DSC180Malware/m2v-adversarial-hindroid

# %% [markdown]
# ## Brainstorming
# Two attack methods used in Android HIV:
# - Jacobian Saliency Map Attack:  `art.attacks.evasion.SaliencyMapMethod`
# - Carlini and Wagner L_2 Attack:  `art.attacks.evasion.CarliniL2Method`

# %% [markdown]
# I don't know how I would utilize those methods, to be frank. If I were to do it from scratch:
#
# Inputs:
# - A trained classifier
# - An app (in the form extracted csvs)
#
# Ouput:
#
# - The app data csv for a perturbed app.
# - Will have noise API calls appended to it.

# %%
outfolder = 'data/out/all-apps/'
apps_df = pd.read_csv('data/out/all-apps/app_list.csv')
app_nodes = apps_df.app.map(
    pd.read_csv(os.path.join(outfolder, 'app_map.csv'), index_col='app').uid
)
[print(app_dir) for app_dir in apps_df[app_nodes.isna()].app_dir]
# Out:
# /teams/DSC180A_FA20_A00/a04malware/malware/Andup/variety1/d0b7d7cf6833148f94a91c25c2546891
# /teams/DSC180A_FA20_A00/a04malware/malware/SimpleLocker/variety4/929ffcc1b2972c240e64814dbced5c2b
# [None, None]

# %%
pd.read_csv('data/out/all-apps/app-data/929ffcc1b2972c240e64814dbced5c2b.csv')
# Out:
# Empty DataFrame
# Columns: [app, api, invoke_type, class, method, package, context]
# Index: []

# %%
app_nodes
# Out:
# 0          app0
# 1          app1
# 2          app2
# 3          app3
# 4          app4
#          ...
# 5482    app5480
# 5483    app5481
# 5484    app5482
# 5485    app5483
# 5486    app5484
# Name: app, Length: 5487, dtype: object

# %%
pd.read_csv(os.path.join(outfolder, 'app_map.csv'), index_col='app').loc[['d0b7d7cf6833148f94a91c25c2546891', '929ffcc1b2972c240e64814dbced5c2b']]
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-16-ce1013a17fd5> in <module>
# ----> 1 pd.read_csv(os.path.join(outfolder, 'app_map.csv'), index_col='app').loc[['d0b7d7cf6833148f94a91c25c2546891', '929ffcc1b2972c240e64814dbced5c2b']]
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     892
#     893             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 894             return self._getitem_axis(maybe_callable, axis=axis)
#     895
#     896     def _is_scalar_access(self, key: Tuple):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1110                     raise ValueError("Cannot index with multidimensional key")
#    1111
# -> 1112                 return self._getitem_iterable(key, axis=axis)
#    1113
#    1114             # nested tuple slicing
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1050
#    1051         # A collection of keys
# -> 1052         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1053         return self.obj._reindex_with_indexers(
#    1054             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1263             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1264
# -> 1265         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1266         return keyarr, indexer
#    1267
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1305             if missing == len(indexer):
#    1306                 axis_name = self.obj._get_axis_name(axis)
# -> 1307                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1308
#    1309             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['d0b7d7cf6833148f94a91c25c2546891', '929ffcc1b2972c240e64814dbced5c2b'], dtype='object', name='app')] are in the [index]"

# %%
miniset_folder = os.path.join('data', 'out', 'miniset')

# %%
# create/load mini dataset
# all_apps = pd.read_csv('data/out/all-apps/all_apps.csv')
# popular_apps = all_apps[all_apps.category=='popular-apps']
# malware_sample = all_apps[all_apps.category=='malware'].sample(popular_apps.shape[0])
# miniset = pd.concat([popular_apps, malware_sample])
# miniset.to_csv(os.path.join(miniset_folder, "app_list.csv"), index=False)
# miniset_train = miniset.sample(448)
# miniset_train.to_csv('data/out/miniset-train/app_list.csv')
# miniset_test = miniset.loc[miniset.index.difference(miniset_train.index)]
# miniset_test.to_csv('data/out/miniset-test/app_list.csv')
miniset = pd.read_csv(os.path.join(miniset_folder, "app_list.csv"), index_col='app')
miniset_train = pd.read_csv('data/out/miniset-train/app_list.csv', index_col='app')
miniset_test = pd.read_csv('data/out/miniset-test/app_list.csv', index_col='app')
miniset.shape, miniset_train.shape, miniset_test.shape
# Out:
# ((648, 2), (448, 2), (200, 2))

# %% [markdown]
# After running the ETL and generating features for this dataset, measure the baseline performance.

# %%
baseline_features = pd.read_csv(os.path.join(miniset_folder, "features.csv"), index_col='app')
baseline_features['label'] = (miniset.category=='malware').astype(int)
# X, y = baseline_features.loc[:,'0':'127'], baseline_features.label
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)
X_train, y_train, X_test, y_test = (
    baseline_features.loc[list(miniset_train.index), '0':'127'],
    baseline_features.loc[list(miniset_train.index), 'label'],
    baseline_features.loc[list(miniset_test.index), '0':'127'],
    baseline_features.loc[list(miniset_test.index), 'label']
)

# %%
model = RandomForestClassifier(n_estimators=50, max_depth=3,n_jobs=-1)  # probably overfit
model.fit(X_train, y_train)

print(classification_report(model.predict(X_train), y_train))
print(classification_report(model.predict(X_test), y_test))
f1_score(model.predict(X_test), y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       222
#            1       0.99      0.95      0.97       226
#
#     accuracy                           0.97       448
#    macro avg       0.97      0.97      0.97       448
# weighted avg       0.97      0.97      0.97       448
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98        94
#            1       0.97      0.99      0.98       106
#
#     accuracy                           0.98       200
#    macro avg       0.98      0.98      0.98       200
# weighted avg       0.98      0.98      0.98       200
# 0.9813084112149533

# %%
app_map = pd.read_csv(os.path.join(miniset_folder, "app_map.csv"), index_col='uid')
app_map['malware'] = app_map.app.map(miniset.category=='malware')
edges = pd.read_csv(os.path.join(miniset_folder, "edges.csv")).drop_duplicates()
edges
# Out:
#                  source      target
# 0                  app0        api0
# 1                  app0        api1
# 2                  app0        api2
# 3                  app0        api3
# 4                  app0        api4
# ...                 ...         ...
# 29509951  package342559  api3312270
# 29509952  package342559  api3312271
# 29509953  package342559  api3312272
# 29509954  package342559  api3312273
# 29509955  package342559  api3312274
#
# [29509956 rows x 2 columns]

# %%
# make pool of apis only used by benign apps
app_api_edges = edges[edges.source.str.startswith('app')]#.set_index('source')

malignant_app_apis = app_api_edges[app_api_edges.source.map(app_map.malware)]
benign_apis = app_api_edges.drop(malignant_app_apis.index).target.unique()
print(benign_apis.size)
benign_apis
# Out:
# 3127432
# array(['api0', 'api1', 'api2', ..., 'api3127429', 'api3127430',
#        'api3127431'], dtype=object)

# %%
# load nodes
with open(os.path.join(miniset_folder,'graph.pkl'), 'rb') as file:
    g = pickle.load(file)
with open(os.path.join(miniset_folder,'graph.pkl'), 'wb') as file:
    pickle.dump(g, file)
    
nodes = {}
for node_type in ['app', 'api', 'method', 'package']:
    nodes[node_type] = IndexedArray(index=g.nodes()[g.nodes().str.startswith(node_type)])

# %%
# counts = app_api_edges.source.value_counts().to_frame()
# counts['malware'] = app_map.malware
# counts.index = counts.index.map(app_map.app)
# counts.iloc[-200:-150]

# %%
walk_args = {
    "nprocs": 8,
    "length": 60,
    "n": 3,
    "metapaths": [
        ["app", "api", "app"],
        ["app", "api", "method", "api", "app"],
        ["app", "api", "package", "api", "app"],
        ["app", "api", "package", "api", "method", "api", "app"],
        ["app", "api", "method", "api", "package", "api", "app"]
    ]
}
w2v_args = {
    "size": 128,
    "window": 5,
    "min_count": 0,
    "sg": 1,
    "workers": 16,
    "iter": 5
}

# %%
data = []
for i in range(5):
    data.append([i, i])
data
# Out:
# [[0, 0], [1, 1], [2, 2], [3, 3], [4, 4]]

# %%
performance_data = []
    
for num_samples in [int((np.e/2)**i) for i in range(20) if int((np.e/2)**i)!=1]:
    new_edges = []
    for app_uid in baseline_features.uid[X_test.index]: # for each malignant app
        new_edges.append(
            pd.DataFrame().assign(
                source=[app_uid]*num_samples,
                target=pd.Series(benign_apis).sample(num_samples).reset_index(drop=True)
            )
        )
    new_edges = pd.concat(
        [edges, pd.concat(new_edges, ignore_index=True)], ignore_index=True)
    
    g = StellarGraph(nodes, new_edges.drop_duplicates())
    
    # random walk on all apps, save to metapath_walk.json
    print('Performing random walks')
    rw = UniformRandomMetaPathWalk(g)
    app_nodes = g.nodes()
    
    def run_walks(metapath):
        return rw.run(app_nodes, n=1, length=walk_args['length'], metapaths=[metapath])
    
    metapaths = [walk_args['metapaths'][i%len(walk_args['metapaths'])] for i in range(len(walk_args['metapaths'])*walk_args['n'])]
    metapath_walks = np.concatenate(p_umap(run_walks, metapaths, num_cpus=walk_args['nprocs'])).tolist()
            
    print('Running Word2vec')
    w2v = Word2Vec(metapath_walks, **w2v_args)

    features = pd.DataFrame(w2v.wv.vectors)
    features['uid'] = w2v.wv.index2word
    features['app'] = features['uid'].map(
        pd.read_csv(os.path.join(miniset_folder, 'app_map.csv'), index_col='uid').app
    )
    features = features[features.uid.str.contains('app')].set_index('app')
    features['label'] = (miniset.category=='malware').astype(int)
    
    ptbd_X_train, ptbd_y_test, ptbd_X_test, ptbd_y_train = (
        features.loc[list(miniset_train.index), 0:127],
        features.loc[list(miniset_train.index), 'label'],
        features.loc[list(miniset_test.index), 0:127],
        features.loc[list(miniset_test.index), 'label']
    )

    model = RandomForestClassifier(n_estimators=50, max_depth=2, n_jobs=-1)
    model.fit(ptbd_X_train, ptbd_y_train) # train on normal data

    print(classification_report(model.predict(ptbd_X_test), ptbd_y_test))
    f1 = f1_score(model.predict(ptbd_X_test), ptbd_y_test)
    performance_data.append([num_samples, f1])
# Out:
# Performing random walks
#   0%|          | 0/15 [00:00<?, ?it/s]
# Running Word2vec
# ValueErrorTraceback (most recent call last)
# <ipython-input-13-00f08fa216cf> in <module>
#      50
#      51     model = RandomForestClassifier(n_estimators=50, max_depth=2, n_jobs=-1)
# ---> 52     model.fit(ptbd_X_train, ptbd_y_train) # train on normal data
#      53
#      54     print(classification_report(model.predict(ptbd_X_test), ptbd_y_test))
#
# /opt/conda/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     301                 "sparse multilabel-indicator for y is not supported."
#     302             )
# --> 303         X, y = self._validate_data(X, y, multi_output=True,
#     304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#
# /opt/conda/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# /opt/conda/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/conda/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     810         y = y.astype(np.float64)
#     811
# --> 812     check_consistent_length(X, y)
#     813
#     814     return X, y
#
# /opt/conda/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     253     uniques = np.unique(lengths)
#     254     if len(uniques) > 1:
# --> 255         raise ValueError("Found input variables with inconsistent numbers of"
#     256                          " samples: %r" % [int(l) for l in lengths])
#     257
#
# ValueError: Found input variables with inconsistent numbers of samples: [448, 200]

# %%
performance_df = pd.DataFrame(performance_data, columns=['APIs Inserted', 'f1-score'])
performance_df

# %%
# random walk on all apps, save to metapath_walk.json
print('Performing random walks')
rw = UniformRandomMetaPathWalk(g)
app_nodes = list(g.nodes()[g.nodes().str.contains('app')])

def run_walks(metapath):
    return rw.run(app_nodes, n=1, length=walk_args['length'], metapaths=[metapath])

metapaths = [walk_args['metapaths'][i%len(walk_args['metapaths'])] for i in range(len(walk_args['metapaths'])*walk_args['n'])]
metapath_walks = np.concatenate(p_umap(run_walks, metapaths, num_cpus=walk_args['nprocs'])).tolist()
# with open(metapath_walk_outpath, 'w') as file:
#     json.dump(metapath_walks, file)
# Out:
# Performing random walks
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
print('Running Word2vec')
w2v = Word2Vec(metapath_walks, **w2v_args)

features = pd.DataFrame(w2v.wv.vectors)
features['uid'] = w2v.wv.index2word
features['app'] = features['uid'].map(
    pd.read_csv(os.path.join(miniset_folder, 'app_map.csv'), index_col='uid').app
)
features = features[features.uid.str.contains('app')].set_index('app')
features
# Out:
# Running Word2vec
#                                          0         1         2         3  \
# app
# com.vimage.android               -0.434181  0.904495  0.221625  0.453950
# com.zplayworld.popstar           -0.321782  0.658708  0.217133  0.457418
# com.lulu.lulubox                 -0.304102  0.723962 -0.040271  0.447959
# com.marker.samsara               -0.254549  0.684685  0.120190  0.418753
# com.qihoo.security               -0.200034  0.678715  0.159953  0.387708
# ...                                    ...       ...       ...       ...
# 6d5f69facb4fb030fdc4402e80ec8bf4 -0.010568  0.023965  0.004698  0.013112
# 947a81ff5fc75bc5d3120fcb2560b44a -0.009337  0.032027  0.009047  0.021131
# b192c1bee97c5270f734bc59efad7cc4 -0.007492  0.026591  0.010206  0.014645
# 530f503ab61fcf1e83bc7c99aaf792d6 -0.015314  0.027821  0.004038  0.017082
# a03b3d7daba51161610a7566732defed -0.014706  0.030235  0.007907  0.022578
#
#                                          4         5         6         7  \
# app
# com.vimage.android               -0.037660  0.251947  0.213413 -0.265110
# com.zplayworld.popstar           -0.384150  0.581817  0.313925 -0.821387
# com.lulu.lulubox                 -0.288282  0.596330  0.488771 -0.655010
# com.marker.samsara               -0.261609  0.399931  0.135643 -0.614885
# com.qihoo.security               -0.260823  0.499018  0.474530 -0.798367
# ...                                    ...       ...       ...       ...
# 6d5f69facb4fb030fdc4402e80ec8bf4 -0.013593  0.019785  0.012339 -0.027680
# 947a81ff5fc75bc5d3120fcb2560b44a -0.012736  0.020324  0.012839 -0.026645
# b192c1bee97c5270f734bc59efad7cc4 -0.017613  0.022259  0.020368 -0.029604
# 530f503ab61fcf1e83bc7c99aaf792d6 -0.015717  0.021089  0.017045 -0.029893
# a03b3d7daba51161610a7566732defed -0.013536  0.023962  0.020728 -0.031602
#
#                                          8         9  ...       119       120  \
# app                                                   ...
# com.vimage.android                0.166257  0.080125  ...  0.401366  0.094421
# com.zplayworld.popstar            0.151057  0.560012  ...  0.073903  0.208779
# com.lulu.lulubox                  0.148430  0.552671  ...  0.030009  0.225452
# com.marker.samsara                0.026061  0.407189  ...  0.230456  0.154173
# com.qihoo.security                0.163531  0.400919  ...  0.094478  0.213551
# ...                                    ...       ...  ...       ...       ...
# 6d5f69facb4fb030fdc4402e80ec8bf4  0.005966  0.011774  ...  0.004195  0.015259
# 947a81ff5fc75bc5d3120fcb2560b44a  0.003341  0.014903  ...  0.006778  0.015127
# b192c1bee97c5270f734bc59efad7cc4  0.007487  0.012823  ...  0.004809  0.011810
# 530f503ab61fcf1e83bc7c99aaf792d6  0.005217  0.018604  ...  0.008630  0.019734
# a03b3d7daba51161610a7566732defed  0.007040  0.017853  ...  0.003446  0.013209
#
#                                        121       122       123       124  \
# app
# com.vimage.android               -0.019879  0.490105  0.411732  0.133142
# com.zplayworld.popstar           -0.354540  0.272968  0.624319  0.039289
# com.lulu.lulubox                 -0.359683  0.336802  0.362210  0.038432
# com.marker.samsara               -0.579432  0.213709  0.793994  0.337976
# com.qihoo.security               -0.367226  0.336674  0.685901  0.318732
# ...                                    ...       ...       ...       ...
# 6d5f69facb4fb030fdc4402e80ec8bf4 -0.010092  0.009737  0.024783  0.006813
# 947a81ff5fc75bc5d3120fcb2560b44a -0.014425  0.017712  0.027035  0.008259
# b192c1bee97c5270f734bc59efad7cc4 -0.011709  0.020079  0.030915  0.012302
# 530f503ab61fcf1e83bc7c99aaf792d6 -0.015124  0.010481  0.028630  0.011482
# a03b3d7daba51161610a7566732defed -0.012229  0.014563  0.028232  0.011690
#
#                                        125       126       127     uid
# app
# com.vimage.android               -0.438637  1.482454 -0.241698  app104
# com.zplayworld.popstar            0.012747  1.377997 -0.108074   app22
# com.lulu.lulubox                  0.030904  1.189019  0.150337   app58
# com.marker.samsara               -0.218079  1.438636 -0.101036  app247
# com.qihoo.security                0.006208  1.278291  0.033621   app70
# ...                                    ...       ...       ...     ...
# 6d5f69facb4fb030fdc4402e80ec8bf4  0.002975  0.055303  0.000753  app383
# 947a81ff5fc75bc5d3120fcb2560b44a -0.003955  0.069002 -0.002421  app420
# b192c1bee97c5270f734bc59efad7cc4  0.003673  0.064613 -0.000503  app434
# 530f503ab61fcf1e83bc7c99aaf792d6 -0.005701  0.061374  0.001228  app436
# a03b3d7daba51161610a7566732defed -0.001591  0.060070 -0.002616  app602
#
# [648 rows x 129 columns]

# %%
features['label'] = (miniset.category=='malware').astype(int)
features
# Out:
#                                          0         1         2         3  \
# app
# com.vimage.android               -0.434181  0.904495  0.221625  0.453950
# com.zplayworld.popstar           -0.321782  0.658708  0.217133  0.457418
# com.lulu.lulubox                 -0.304102  0.723962 -0.040271  0.447959
# com.marker.samsara               -0.254549  0.684685  0.120190  0.418753
# com.qihoo.security               -0.200034  0.678715  0.159953  0.387708
# ...                                    ...       ...       ...       ...
# 6d5f69facb4fb030fdc4402e80ec8bf4 -0.010568  0.023965  0.004698  0.013112
# 947a81ff5fc75bc5d3120fcb2560b44a -0.009337  0.032027  0.009047  0.021131
# b192c1bee97c5270f734bc59efad7cc4 -0.007492  0.026591  0.010206  0.014645
# 530f503ab61fcf1e83bc7c99aaf792d6 -0.015314  0.027821  0.004038  0.017082
# a03b3d7daba51161610a7566732defed -0.014706  0.030235  0.007907  0.022578
#
#                                          4         5         6         7  \
# app
# com.vimage.android               -0.037660  0.251947  0.213413 -0.265110
# com.zplayworld.popstar           -0.384150  0.581817  0.313925 -0.821387
# com.lulu.lulubox                 -0.288282  0.596330  0.488771 -0.655010
# com.marker.samsara               -0.261609  0.399931  0.135643 -0.614885
# com.qihoo.security               -0.260823  0.499018  0.474530 -0.798367
# ...                                    ...       ...       ...       ...
# 6d5f69facb4fb030fdc4402e80ec8bf4 -0.013593  0.019785  0.012339 -0.027680
# 947a81ff5fc75bc5d3120fcb2560b44a -0.012736  0.020324  0.012839 -0.026645
# b192c1bee97c5270f734bc59efad7cc4 -0.017613  0.022259  0.020368 -0.029604
# 530f503ab61fcf1e83bc7c99aaf792d6 -0.015717  0.021089  0.017045 -0.029893
# a03b3d7daba51161610a7566732defed -0.013536  0.023962  0.020728 -0.031602
#
#                                          8         9  ...       120       121  \
# app                                                   ...
# com.vimage.android                0.166257  0.080125  ...  0.094421 -0.019879
# com.zplayworld.popstar            0.151057  0.560012  ...  0.208779 -0.354540
# com.lulu.lulubox                  0.148430  0.552671  ...  0.225452 -0.359683
# com.marker.samsara                0.026061  0.407189  ...  0.154173 -0.579432
# com.qihoo.security                0.163531  0.400919  ...  0.213551 -0.367226
# ...                                    ...       ...  ...       ...       ...
# 6d5f69facb4fb030fdc4402e80ec8bf4  0.005966  0.011774  ...  0.015259 -0.010092
# 947a81ff5fc75bc5d3120fcb2560b44a  0.003341  0.014903  ...  0.015127 -0.014425
# b192c1bee97c5270f734bc59efad7cc4  0.007487  0.012823  ...  0.011810 -0.011709
# 530f503ab61fcf1e83bc7c99aaf792d6  0.005217  0.018604  ...  0.019734 -0.015124
# a03b3d7daba51161610a7566732defed  0.007040  0.017853  ...  0.013209 -0.012229
#
#                                        122       123       124       125  \
# app
# com.vimage.android                0.490105  0.411732  0.133142 -0.438637
# com.zplayworld.popstar            0.272968  0.624319  0.039289  0.012747
# com.lulu.lulubox                  0.336802  0.362210  0.038432  0.030904
# com.marker.samsara                0.213709  0.793994  0.337976 -0.218079
# com.qihoo.security                0.336674  0.685901  0.318732  0.006208
# ...                                    ...       ...       ...       ...
# 6d5f69facb4fb030fdc4402e80ec8bf4  0.009737  0.024783  0.006813  0.002975
# 947a81ff5fc75bc5d3120fcb2560b44a  0.017712  0.027035  0.008259 -0.003955
# b192c1bee97c5270f734bc59efad7cc4  0.020079  0.030915  0.012302  0.003673
# 530f503ab61fcf1e83bc7c99aaf792d6  0.010481  0.028630  0.011482 -0.005701
# a03b3d7daba51161610a7566732defed  0.014563  0.028232  0.011690 -0.001591
#
#                                        126       127     uid  label
# app
# com.vimage.android                1.482454 -0.241698  app104      0
# com.zplayworld.popstar            1.377997 -0.108074   app22      0
# com.lulu.lulubox                  1.189019  0.150337   app58      0
# com.marker.samsara                1.438636 -0.101036  app247      0
# com.qihoo.security                1.278291  0.033621   app70      0
# ...                                    ...       ...     ...    ...
# 6d5f69facb4fb030fdc4402e80ec8bf4  0.055303  0.000753  app383      1
# 947a81ff5fc75bc5d3120fcb2560b44a  0.069002 -0.002421  app420      1
# b192c1bee97c5270f734bc59efad7cc4  0.064613 -0.000503  app434      1
# 530f503ab61fcf1e83bc7c99aaf792d6  0.061374  0.001228  app436      1
# a03b3d7daba51161610a7566732defed  0.060070 -0.002616  app602      1
#
# [648 rows x 130 columns]

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       140
#            1       0.99      0.94      0.96       184
#
#     accuracy                           0.96       324
#    macro avg       0.96      0.96      0.96       324
# weighted avg       0.96      0.96      0.96       324
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.70      0.82       243
#            1       0.52      0.95      0.67        81
#
#     accuracy                           0.77       324
#    macro avg       0.75      0.83      0.74       324
# weighted avg       0.86      0.77      0.78       324
# 0.6695652173913044
